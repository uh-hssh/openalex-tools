# %%
import pandas as pd
from pybliometrics.scopus import ScopusSearch
from pybliometrics.scopus import AbstractRetrieval

# %%
be_journals = [
    'Experimental Economics',
    'Journal of Behavioral and Experimental Economics',
    'Journal of Economic Behavior & Organization',
    'Journal of Behavioral and Experimental Finance',
    'Behavioral Public Policy',
    'Behavioral Science and Policy',
    'Decision',
    'Frontiers in Behavioral Economics',
    'Journal of Behavioral Economics for Policy',
    'Journal of Behavioural Economics and Social Systems',
    'Journal of Consumer Research',
    'Journal of Economics and Behavioral Studies',
    'Journal of Neuroscience, Psychology and Economics',
    'Journal of Risk and Uncertainty',
    'Review of Behavioral Economics',
    'Rationality and Society',
    'International Journal of Social Economics',
    'Organizational Behavior and Human Decision Processes',
    'Journal of Behavioral Decision Making',
    'Journal of Consumer Psychology',
    'Journal of Economic Psychology',
    'Judgment and Decision Making',
    'Organizational Behavior and Human Decision Processes',
    'Mind & Society',
    'Policy Insights from the Behavioral and Brain Sciences',
    'Nature Human Behaviour',
    'Current Opinion in Behavioral Sciences',
    'Behavioral Sciences',
    'Journal of the Experimental Analysis of Behavior'
    
]

techlaw_journals= [
    'Journal of Technology Law & Policy',
    'Computer Law & Security Review',
    'Journal of Intellectual Property Law & Practice ',
    'Jurimetrics ','Journal of High Technology Law ',
    'The Journal of Media Law ','Artificial Intelligence & Law',
    'Technology and Regulation','Internet Policy Review',
    'Computer Law Review International',
    'Law, Technology and Innovation',
    'Industrial Law Journal',
    'Journal of Responsible Technology',
    'European Journal of Risk Regulation',
    'European Data Protection Law Review',
    'International Data Privacy Law',
    'International Journal of Law and Information Technology',
    'International Review of Law, Computers and Technology',
    'Journal of International Commercial Law and Technology',
    'Journal of Cross-Disciplinary Research in Computational Law',
    'Journal of Telecommunications and High Technology Law',
    'Masaryk University Journal of Law and Technology',
    'Information & Communications Technology Law',
    'Journal of European Tort Law',
    'European Review of Private Law',
    'Journal of Cybersecurity',
    'Global Privacy Law Review',
    'Behavioural Science and Law',
    'Journal of Business and Technology Law',
    'Studies in Ethics, Law, and Technology',
    'European Journal of Law and Technology',
    'SCRIPTed: A Journal of Law, Technology and Society',
    'International Cybersecurity Law Review',
    'IIC - International Review of Intellectual Property and Competition Law',
    'Queen Mary Journal of Intellectual Property',
    'Regulation and Governance',
    'Journal of European Consumer and Market Law'
]

j_list = journals.split(' or ')

# %%
query = " or ".join( j_list[0:10] )

# %%
s = ScopusSearch(
    'SRCTITLE(' + query + ')',
)

# %%
df = pd.DataFrame(s.results)
df
# Out:
#                     eid   doi   pii pubmed_id  \
# 0    2-s2.0-85015606798  None  None  28233969
# 1    2-s2.0-85015578792  None  None  28233970
# 2    2-s2.0-85049844255  None  None  29989758
# 3    2-s2.0-85015581621  None  None  28225582
# 4    2-s2.0-84979819352  None  None  27071222
# ..                  ...   ...   ...       ...
# 222   2-s2.0-0015769162  None  None  11663363
# 223   2-s2.0-0015769149  None  None  11660993
# 224   2-s2.0-0015663561  None  None  11664270
# 225   2-s2.0-0015599019  None  None  11664294
# 226   2-s2.0-0015598994  None  None  11664274
#
#                                                  title subtype  \
# 0    A Different Class of Care: the Benefits Crisis...      ar
# 1    Using Data Exclusivity Grants to Incentivize C...      ar
# 2    Identity and Narrative: Turning Oppression Int...      ar
# 3    Bib Pharma Monopoly: Why Consumers Keep Landin...      ar
# 4    BRIDGING THE GAP BETWEEN THE “HAVE” AND THE “H...      ar
# ..                                                 ...     ...
# 222  The abortion cases: a return to Lochner, or a ...      ar
# 223                     Consent to surgery--a dilemma.      ar
# 224  Artificial insemination: problems, policies, a...      ar
# 225  Texas involuntary commitment laws--unconstitut...      ar
# 226  Domestic relations--necessity of blood transfu...      ar
#
#     subtypeDescription         creator      afid            affilname  ...  \
# 0              Article        Jones T.  60008724      Duke University  ...
# 1              Article       Levi E.L.  60020420  American University  ...
# 2              Article       Newman J.  60029251  University of Miami  ...
# 3              Article         Levy M.      None                 None  ...
# 4              Article  Mastroianni M.      None                 None  ...
# ..                 ...             ...       ...                  ...  ...
# 222            Article            None      None                 None  ...
# 223            Article            None      None                 None  ...
# 224            Article         Carr J.      None                 None  ...
# 225            Article       MacRae L.      None                 None  ...
# 226            Article        Hulen M.      None                 None  ...
#
#     pageRange                                        description authkeywords  \
# 0     691-760  When compared to other developed nations, the ...         None
# 1     911-970  The pharmaceutical market is divided into two ...         None
# 2     373-402                                               None         None
# 3     247-303  Now, more than ever before, pharmacologists ar...         None
# 4     151-181                                               None         None
# ..        ...                                                ...          ...
# 222   776-797                                               None         None
# 223   591-602                                               None         None
# 224   120-162                                               None         None
# 225   273-282                                               None         None
# 226   151-156                                               None         None
#
#     citedby_count openaccess freetoread freetoreadLabel fund_acr    fund_no  \
# 0               5          0       None            None     None  undefined
# 1               5          0       None            None     None  undefined
# 2               3          0       None            None     None  undefined
# 3               2          0       None            None     None  undefined
# 4               2          0       None            None     None  undefined
# ..            ...        ...        ...             ...      ...        ...
# 222             0          0       None            None     None  undefined
# 223             0          0       None            None     None  undefined
# 224             2          0       None            None     None  undefined
# 225             0          0       None            None     None  undefined
# 226             0          0       None            None     None  undefined
#
#     fund_sponsor
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
# ..           ...
# 222         None
# 223         None
# 224         None
# 225         None
# 226         None
#
# [227 rows x 36 columns]

# %%
df.to_csv("data_scopus/aglr_7.csv", index=False)

# %%
s.get_key_remaining_quota()
# Out:
# '18499'

# %% [markdown]
# ### Abstracts

# %%
df = pd.read_csv("data_scopus/aglr.csv")
# Out:
# /var/folders/f5/rvzjs9mx3vgdk4s76v2jw_tdrq3gy7/T/ipykernel_92701/1131900794.py:1: DtypeWarning: Columns (2,21,23,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data_scopus/aglr.csv")

# %%
df['abstract'] = ''
eids = df['eid']

# %%
for i in range(0, len(df)):
    ab = AbstractRetrieval(eids[i], view='FULL', id_type='eid')
    
    print(i, end="\r")
    
    if ab.abstract != None:
        df.loc[i, 'abstract'] = ab.abstract
    else:
        df.loc[i, 'abstract'] = ab.description
# Out:
# 2979
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[133], line 2
#       1 for i in range(0, len(df)):
# ----> 2     ab = AbstractRetrieval(eids[i], view='FULL', id_type='eid')
#       4     print(i, end="\r")
#       6     if ab.abstract != None:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pybliometrics/scopus/abstract_retrieval.py:703, in AbstractRetrieval.__init__(self, identifier, refresh, view, id_type, **kwds)
#     701 self._view = view
#     702 self._refresh = refresh
# --> 703 Retrieval.__init__(self, identifier=identifier, id_type=id_type,
#     704                    api='AbstractRetrieval', **kwds)
#     705 self._json = self._json['abstracts-retrieval-response']
#     706 self._head = chained_get(self._json, ["item", "bibrecord", "head"], {})
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pybliometrics/scopus/superclasses/retrieval.py:48, in Retrieval.__init__(self, identifier, api, id_type, **kwds)
#      46 # Parse file contents
#      47 params = {'view': self._view, **kwds}
# ---> 48 Base.__init__(self, params=params, url=url, api=api)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pybliometrics/scopus/superclasses/base.py:59, in Base.__init__(self, params, url, api, download, verbose, *args, **kwds)
#      57         self._json = loads(fname.read_text())
#      58 else:
# ---> 59     resp = get_content(url, api, params, *args, **kwds)
#      60     header = resp.headers
#      61     if search_request:
#      62         # Get number of results
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pybliometrics/scopus/utils/get_content.py:88, in get_content(url, api, params, **kwds)
#      86 # Perform request, eventually replacing the current key
#      87 timeout = config.getint("Requests", "Timeout", fallback=20)
# ---> 88 resp = session.get(url, headers=header, proxies=proxies, params=params,
#      89                   timeout=timeout)
#      90 while resp.status_code == 429:
#      91     try:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:600, in Session.get(self, url, **kwargs)
#     592 r"""Sends a GET request. Returns :class:`Response` object.
#     593
#     594 :param url: URL for the new :class:`Request` object.
#     595 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     596 :rtype: requests.Response
#     597 """
#     599 kwargs.setdefault("allow_redirects", True)
# --> 600 return self.request("GET", url, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:1368, in HTTPConnection.getresponse(self)
#    1366 try:
#    1367     try:
# -> 1368         response.begin()
#    1369     except ConnectionError:
#    1370         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:317, in HTTPResponse.begin(self)
#     315 # read until we get a non-100 response
#     316 while True:
# --> 317     version, status, reason = self._read_status()
#     318     if status != CONTINUE:
#     319         break
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:278, in HTTPResponse._read_status(self)
#     277 def _read_status(self):
# --> 278     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     279     if len(line) > _MAXLINE:
#     280         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1273, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1269     if flags != 0:
#    1270         raise ValueError(
#    1271           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1272           self.__class__)
# -> 1273     return self.read(nbytes, buffer)
#    1274 else:
#    1275     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1129, in SSLSocket.read(self, len, buffer)
#    1127 try:
#    1128     if buffer is not None:
# -> 1129         return self._sslobj.read(len, buffer)
#    1130     else:
#    1131         return self._sslobj.read(len)
#
# KeyboardInterrupt:
